# %% [markdown]
# <a href="https://colab.research.google.com/github/team0243/data_viz_2022/blob/main/data_viz_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project กลุ่ม Therapy Python**
#
# ``ทำ Dashboard ของ Data Covid (ตั้งแต่วันที่ 12/01/2020 - 20/03/2022) เล่ามุมมองที่เราเลือกเอง + ใช้ข้อมูลภูมิภาค + ข้อมูลอื่นที่เลือกเอง``
# ``
# เริ่มพรีเซ็นต์ 25 มีค 30 มีค 1 เมษา
# ``
#
# ** ที่มาของข้อมูล **
#
# 1.ข้อมูลรายงาน COVID-19 ประจำประเทศไทย
#
# https://data.go.th/dataset/covid-19-daily ประกอบด้วย 4 ชุดข้อมูลได้แก่
#
# 1.1 รายงานจำนวนผู้ติดเชื้อ COVID-19 ตั้งแต่วันที่ 12 มกราคม 2564 ถึงวันที่ 11 สิงหาคม 2564
#
# 1.2 รายงานจำนวนผู้ติดเชื้อ COVID-19 ตั้งแต่วันที่ 12 สิงหาคม 2564 ถึงวันที่ 25 ตุลาคม 2564
#
# 1.3 รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน ตั้งแต่วันที่ 25 ตุลาคม 2564 ถึงวันที่ 27 กุมภาพันธ์ 2565
#
# 1.4 รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน ตั้งแต่วันที่ 28 กุมภาพันธ์ 2565 ถึงวันที่ 20 มีนาคม 2565
#
# 2.ข้อมูลในแต่ละภูมิภาค
#
# 3.ข้อมูลปริมาณการใช้งานเน็ตประชารัฐ
#
# https://data.go.th/dataset/village_internet_usage

# %% [markdown]
# ## อัพโหลดข้อมูลจาก Drive
#
# **Import data**

# %%
import numpy as np

# %%
import pandas as pd     # pandas ใช้จัดการข้อมูลที่เป็นตาราง
import os       # os ใช้จัดการกับไฟล์ ว่าอยู่ที่ไหน

# %%
from google.colab import drive      # ชี้ไฟล์ที่อยู่ใน google drive เพื่อเชื่อมต่อไฟล์
drive.mount('/content/drive')
path =  '/content/drive/My Drive/Data_viz_project'    # ชี้ dirve ที่เราต้องการ
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## เตรียมข้อมูลData covid ทั้ง 4 ชุด

# %% [markdown]
# ข้อมูลชุดที่ 1  รายงานจำนวนผู้ติดเชื้อ COVID-19 ตั้งแต่วันที่ 12 มกราคม 2563 ถึงวันที่ 11 สิงหาคม 2564

# %%
data_file_path = os.path.join(path,'confirmed-cases.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_covid1 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
display(data_covid1.head(2),data_covid1.tail(2))
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1    2    2020-01-17           NaT  หญิง  74.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0               NaN
# 1               NaN
#            No. announce_date Notified date   sex   age Unit nationality  \
# 816987  816988    2021-08-11    2021-08-10  หญิง  34.0   ปี    Thailand
# 816988  816989    2021-08-11    2021-08-10  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation   risk province_of_onset district_of_onset
# 816987               สระแก้ว  อื่นๆ     กรุงเทพมหานคร       บางขุนเทียน
# 816988               สระแก้ว  อื่นๆ   พระนครศรีอยุธยา             อุทัย

# %%
import datetime

# %%
data_t = pd.DataFrame(data_covid1)
data_t['announce_date'] = pd.to_datetime(data_covid1['announce_date'], format = "%d/%m/%Y")
#data_t['year'] = data_t['announce_date'].dt.year
#data_t['month'] = data_t['announce_date'].dt.month

# %%
#search.info()

# %%
data_covid1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816989 entries, 0 to 816988
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   No.                    816989 non-null  int64
#  1   announce_date          816989 non-null  datetime64[ns]
#  2   Notified date          814194 non-null  datetime64[ns]
#  3   sex                    763984 non-null  object
#  4   age                    742211 non-null  float64
#  5   Unit                   742352 non-null  object
#  6   nationality            734913 non-null  object
#  7   province_of_isolation  816717 non-null  object
#  8   risk                   815895 non-null  object
#  9   province_of_onset      719877 non-null  object
#  10  district_of_onset      661689 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7)
# memory usage: 68.6+ MB

# %% [markdown]
# 1.ใช้ fillna() เปลี่ยนข้อมูลที่มีค่า NaN เป็นค่าที่ระบุ

# %%
data_covid1up = data_covid1.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  
data_covid1up.head()
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1    2020-01-12   ไม่มีข้อมูล  หญิง  61.0   ปี       China
# 1    2    2020-01-17   ไม่มีข้อมูล  หญิง  74.0   ปี       China
# 2    3    2020-01-22   ไม่มีข้อมูล  หญิง  73.0   ปี    Thailand
# 3    4    2020-01-22   ไม่มีข้อมูล   ชาย  68.0   ปี       China
# 4    5    2020-01-24   ไม่มีข้อมูล  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0       ไม่มีข้อมูล
# 1       ไม่มีข้อมูล
# 2             เมือง
# 3       ไม่มีข้อมูล
# ...

# %%
data_covid1up.isnull().any() # พบว่า ฟิวด์ age  มี ค่า Missing
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                       True
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# 2.ฟิวด์ age เปลี่ยนค่า Nan ให้เป็นค่าเฉลี่ย ของอายุ

# %%
data_covid1[['age']].describe()
# Out:
#                  age
# count  742211.000000
# mean       35.677040
# std        16.567625
# min         0.750000
# 25%        24.000000
# 50%        34.000000
# 75%        46.000000
# max       440.000000

# %%
data_covid_m1 = data_covid1up.fillna(value={'age':data_covid1['age'].mean()})  #ฟิวด์ age เปลี่ยนค่า Nan ให้เป็นค่าเฉลี่ย ของอายุ

# %%
data_covid_m1
# Out:
#            No. announce_date        Notified date   sex   age Unit  \
# 0            1    2020-01-12          ไม่มีข้อมูล  หญิง  61.0   ปี
# 1            2    2020-01-17          ไม่มีข้อมูล  หญิง  74.0   ปี
# 2            3    2020-01-22          ไม่มีข้อมูล  หญิง  73.0   ปี
# 3            4    2020-01-22          ไม่มีข้อมูล   ชาย  68.0   ปี
# 4            5    2020-01-24          ไม่มีข้อมูล  หญิง  66.0   ปี
# ...        ...           ...                  ...   ...   ...  ...
# 816984  816985    2021-08-11  2021-08-10 00:00:00  หญิง   8.0   ปี
# 816985  816986    2021-08-11  2021-08-10 00:00:00   ชาย  14.0   ปี
# 816986  816987    2021-08-11  2021-08-10 00:00:00   ชาย  59.0   ปี
# 816987  816988    2021-08-11  2021-08-10 00:00:00  หญิง  34.0   ปี
# 816988  816989    2021-08-11  2021-08-10 00:00:00  หญิง  19.0   ปี
#
#        nationality province_of_isolation  \
# 0            China         กรุงเทพมหานคร
# 1            China         กรุงเทพมหานคร
# ...

# %%
data_covid_m1.isnull().any()  # พบว่าฟิว์ดของ sex ไม่มี missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ข้อมูลชุดที่ 2 รายงานจำนวนผู้ติดเชื้อ COVID-19 ตั้งแต่วันที่ 12 สิงหาคม 2564 ถึงวันที่ 25 ตุลาคม 2564

# %%
data_file_path = os.path.join(path,'confirmed-cases-since-120864.csv')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_covid2 = pd.read_csv(data_file_path)   # อ่านไฟล์ csv

# %%
display(data_covid2.head(2),data_covid2.tail(2))
# Out:
#       No. announce_date Notified date  sex  age Unit nationality  \
# 0  816990     12/8/2021     11/8/2021  ชาย  7.0   ปี    Thailand
# 1  816991     12/8/2021     11/8/2021  ชาย  1.0   ปี    Thailand
#
#   province_of_isolation   risk province_of_onset district_of_onset
# 0              เชียงราย  อื่นๆ               NaN               NaN
# 1              เชียงราย  อื่นๆ               NaN               NaN
#              No. announce_date Notified date  sex   age Unit nationality  \
# 1042166  1859156    25/10/2021    24/10/2021  ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021  ชาย  25.0   ปี         NaN
#
#         province_of_isolation              risk province_of_onset  \
# 1042166         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ               NaN
# 1042167             เชียงใหม่  ทัณฑสถาน/เรือนจำ               NaN
#
#         district_of_onset
# 1042166               NaN
# 1042167               NaN

# %%
data_t = pd.DataFrame(data_covid2)
data_t['announce_date'] = pd.to_datetime(data_covid2['announce_date'], format = "%d/%m/%Y")

# %%
data_covid2.isnull().any() #ตรวจสอบค่า Missing
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# 1.ใช้ fillna() เปลี่ยนข้อมูลที่มีค่า NaN เป็นค่าที่ระบุ

# %%
data_covid2up = data_covid1.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  
data_covid2up.head()
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1    2020-01-12   ไม่มีข้อมูล  หญิง  61.0   ปี       China
# 1    2    2020-01-17   ไม่มีข้อมูล  หญิง  74.0   ปี       China
# 2    3    2020-01-22   ไม่มีข้อมูล  หญิง  73.0   ปี    Thailand
# 3    4    2020-01-22   ไม่มีข้อมูล   ชาย  68.0   ปี       China
# 4    5    2020-01-24   ไม่มีข้อมูล  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0       ไม่มีข้อมูล
# 1       ไม่มีข้อมูล
# 2             เมือง
# 3       ไม่มีข้อมูล
# ...

# %% [markdown]
# 2.ฟิวด์ age เปลี่ยนค่า Nan ให้เป็นค่าเฉลี่ย ของอายุ

# %%
data_covid_m2 = data_covid2up.fillna(value={'age':data_covid2['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_m2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
data_covid_m2
# Out:
#            No. announce_date        Notified date   sex   age Unit  \
# 0            1    2020-01-12          ไม่มีข้อมูล  หญิง  61.0   ปี
# 1            2    2020-01-17          ไม่มีข้อมูล  หญิง  74.0   ปี
# 2            3    2020-01-22          ไม่มีข้อมูล  หญิง  73.0   ปี
# 3            4    2020-01-22          ไม่มีข้อมูล   ชาย  68.0   ปี
# 4            5    2020-01-24          ไม่มีข้อมูล  หญิง  66.0   ปี
# ...        ...           ...                  ...   ...   ...  ...
# 816984  816985    2021-08-11  2021-08-10 00:00:00  หญิง   8.0   ปี
# 816985  816986    2021-08-11  2021-08-10 00:00:00   ชาย  14.0   ปี
# 816986  816987    2021-08-11  2021-08-10 00:00:00   ชาย  59.0   ปี
# 816987  816988    2021-08-11  2021-08-10 00:00:00  หญิง  34.0   ปี
# 816988  816989    2021-08-11  2021-08-10 00:00:00  หญิง  19.0   ปี
#
#        nationality province_of_isolation  \
# 0            China         กรุงเทพมหานคร
# 1            China         กรุงเทพมหานคร
# ...

# %% [markdown]
# ข้อมูลชุดที่ 3 รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน ตั้งแต่วันที่ 25ตุลาคม 2564 ถึงวันที่ 27 กุมภาพันธ์ 2565

# %%
data_file_path = os.path.join(path,'confirmed-cases-since-271064.csv')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_covid3 = pd.read_csv(data_file_path)   # อ่านไฟล์ csv
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
display(data_covid3.head(2),data_covid3.tail(2))
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1  1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
#
#   province_of_isolation   risk province_of_onset district_of_onset  \
# 0                 ลำปาง  อื่นๆ             ลำปาง        เมืองลำปาง
# 1                 ลำปาง  อื่นๆ             ลำปาง        เมืองลำปาง
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
#              No. announce_date Notified date  sex  age Unit nationality  \
# 1010457  2869615     27/2/2022     26/2/2022  ชาย  NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022  ชาย  NaN  NaN         NaN
#
#         province_of_isolation              risk province_of_onset  \
# 1010457               ปัตตานี  ทัณฑสถาน/เรือนจำ               NaN
# 1010458               ปัตตานี  ทัณฑสถาน/เรือนจำ               NaN
#
#         district_of_onset  Unnamed: 11
# 1010457               NaN          NaN
# ...

# %%
data_t = pd.DataFrame(data_covid3)
data_t['announce_date'] = pd.to_datetime(data_covid3['announce_date'], format = "%d/%m/%Y")

# %%
data_covid3.isnull().any() #ตรวจสอบค่า Missing
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# Unnamed: 11               True
# dtype: bool

# %% [markdown]
# 1.ใช้ fillna() เปลี่ยนข้อมูลที่มีค่า NaN เป็นค่าที่ระบุ

# %%
data_covid3up = data_covid3.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  
data_covid3up.head()
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  1859158    2021-10-26    25/10/2021   ชาย  20.0   ปี    Thailand
# 1  1859159    2021-10-26    25/10/2021  หญิง  42.0   ปี    Thailand
# 2  1859160    2021-10-26    25/10/2021  หญิง  33.0   ปี    Thailand
# 3  1859161    2021-10-26    25/10/2021  หญิง  52.0   ปี    Thailand
# 4  1859162    2021-10-26    25/10/2021  หญิง  84.0   ปี    Thailand
#
#   province_of_isolation                                           risk  \
# 0                 ลำปาง                                          อื่นๆ
# 1                 ลำปาง                                          อื่นๆ
# 2                 ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                 ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                 ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset  Unnamed: 11
# 0             ลำปาง        เมืองลำปาง          NaN
# ...

# %% [markdown]
# 2.ฟิวด์ age เปลี่ยนค่า Nan ให้เป็นค่าเฉลี่ย ของอายุ

# %%
data_covid_m3 = data_covid3up.fillna(value={'age':data_covid2['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_m3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# Unnamed: 11               True
# dtype: bool

# %%
data_covid_m3
# Out:
#              No. announce_date Notified date   sex        age         Unit  \
# 0        1859158    2021-10-26    25/10/2021   ชาย       20.0           ปี
# 1        1859159    2021-10-26    25/10/2021  หญิง       42.0           ปี
# 2        1859160    2021-10-26    25/10/2021  หญิง       33.0           ปี
# 3        1859161    2021-10-26    25/10/2021  หญิง       52.0           ปี
# 4        1859162    2021-10-26    25/10/2021  หญิง       84.0           ปี
# ...          ...           ...           ...   ...        ...          ...
# 1010454  2869612    2022-02-27     26/2/2022   ชาย  35.258596  ไม่มีข้อมูล
# 1010455  2869613    2022-02-27     26/2/2022   ชาย  35.258596  ไม่มีข้อมูล
# 1010456  2869614    2022-02-27     26/2/2022   ชาย  35.258596  ไม่มีข้อมูล
# 1010457  2869615    2022-02-27     26/2/2022   ชาย  35.258596  ไม่มีข้อมูล
# 1010458  2869616    2022-02-27     26/2/2022   ชาย  35.258596  ไม่มีข้อมูล
#
#          nationality province_of_isolation  \
# ...

# %% [markdown]
# ข้อมูลชุดที่ 4 รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน ตั้งแต่วันที่ 28 กุมภาพันธ์ 2565 ถึงวันที่ 20 มีนาคม 2565

# %%
data_file_path = os.path.join(path,'confirmed-cases-since-280265.csv')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_covid4 = pd.read_csv(data_file_path)   # อ่านไฟล์ csv

# %%
display(data_covid4.head(2),data_covid4.tail(2))
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1  2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
#
#   province_of_isolation                                         risk  \
# 0                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset
# 0             พะเยา        เมืองพะเยา
# 1             พะเยา        เมืองพะเยา
#             No. announce_date Notified date  sex  age Unit nationality  \
# 484351  3353968     20/3/2022     19/3/2022  ชาย  NaN  NaN         NaN
# 484352  3353969     20/3/2022     19/3/2022  ชาย  NaN  NaN         NaN
#
#        province_of_isolation              risk province_of_onset  \
# 484351             เชียงใหม่  ทัณฑสถาน/เรือนจำ               NaN
# 484352             เชียงใหม่  ทัณฑสถาน/เรือนจำ               NaN
#
# ...

# %%
data_t = pd.DataFrame(data_covid4)
data_t['announce_date'] = pd.to_datetime(data_covid4['announce_date'], format = "%d/%m/%Y")

# %%
data_covid4.isnull().any() #
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# 1.ใช้ fillna() เปลี่ยนข้อมูลที่มีค่า NaN เป็นค่าที่ระบุ

# %%
data_covid4up = data_covid4.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  
data_covid4up.head()
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  2869617    2022-02-28     27/2/2022   ชาย  41.0   ปี    Thailand
# 1  2869618    2022-02-28     27/2/2022  หญิง  45.0   ปี    Thailand
# 2  2869619    2022-02-28     27/2/2022  หญิง  40.0   ปี    Thailand
# 3  2869620    2022-02-28     27/2/2022   ชาย  44.0   ปี    Thailand
# 4  2869621    2022-02-28     27/2/2022   ชาย  11.0   ปี    Thailand
#
#   province_of_isolation                                         risk  \
# 0                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset
# 0             พะเยา        เมืองพะเยา
# 1             พะเยา        เมืองพะเยา
# ...

# %% [markdown]
# 2.ฟิวด์ age เปลี่ยนค่า Nan ให้เป็นค่าเฉลี่ย ของอายุ

# %%
data_covid_m4 = data_covid4up .fillna(value={'age':data_covid4['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_m4.isnull().any() #ไม่มี Missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
data_covid_m4
# Out:
#             No. announce_date Notified date   sex        age         Unit  \
# 0       2869617    2022-02-28     27/2/2022   ชาย  41.000000           ปี
# 1       2869618    2022-02-28     27/2/2022  หญิง  45.000000           ปี
# 2       2869619    2022-02-28     27/2/2022  หญิง  40.000000           ปี
# 3       2869620    2022-02-28     27/2/2022   ชาย  44.000000           ปี
# 4       2869621    2022-02-28     27/2/2022   ชาย  11.000000           ปี
# ...         ...           ...           ...   ...        ...          ...
# 484348  3353965    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 484349  3353966    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 484350  3353967    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 484351  3353968    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 484352  3353969    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
#
#         nationality province_of_isolation  \
# ...

# %% [markdown]
# รวมตาราง Covid ทั้ง 4  ตาราง

# %%
data_c1 = pd.concat([data_covid_m1,data_covid_m1],ignore_index=True) # รวมตาราง ที่ 1กับ 2 โดยตารางที่ 2 จะเริ่มนับ No.ต่อจาก ตาราง 1

# %%
data_c2 = pd.concat([data_covid_m3,data_covid_m4],ignore_index=True) # รวมตาราง ที่ 3กับ 4 โดยตารางที่ 4 จะเริ่มนับ No.ต่อจาก ตาราง 3

# %%
data_covid_all = pd.concat([data_c1,data_c2],ignore_index=True)

# %%
data_covid_all
# Out:
#              No. announce_date Notified date   sex        age         Unit  \
# 0              1    2020-01-12   ไม่มีข้อมูล  หญิง       61.0           ปี
# 1              2    2020-01-17   ไม่มีข้อมูล  หญิง       74.0           ปี
# 2              3    2020-01-22   ไม่มีข้อมูล  หญิง       73.0           ปี
# 3              4    2020-01-22   ไม่มีข้อมูล   ชาย       68.0           ปี
# 4              5    2020-01-24   ไม่มีข้อมูล  หญิง       66.0           ปี
# ...          ...           ...           ...   ...        ...          ...
# 3128785  3353965    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 3128786  3353966    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 3128787  3353967    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 3128788  3353968    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 3128789  3353969    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
#
# ...

# %% [markdown]
# ตัด column Unnamed: 11 ออกเนื่องจากไม่ทราบว่าเป็นข้อมูลเกี่ยวกับอะไรและเป็น column ที่ไม่มีความเกี่ยวข้องกัน

# %%
data_covid_all.drop(['Unnamed: 11'], axis=1, inplace=True)
data_covid_all
# Out:
#              No. announce_date Notified date   sex        age         Unit  \
# 0              1    2020-01-12   ไม่มีข้อมูล  หญิง       61.0           ปี
# 1              2    2020-01-17   ไม่มีข้อมูล  หญิง       74.0           ปี
# 2              3    2020-01-22   ไม่มีข้อมูล  หญิง       73.0           ปี
# 3              4    2020-01-22   ไม่มีข้อมูล   ชาย       68.0           ปี
# 4              5    2020-01-24   ไม่มีข้อมูล  หญิง       66.0           ปี
# ...          ...           ...           ...   ...        ...          ...
# 3128785  3353965    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 3128786  3353966    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 3128787  3353967    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 3128788  3353968    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
# 3128789  3353969    2022-03-20     19/3/2022   ชาย  37.265455  ไม่มีข้อมูล
#
# ...

# %% [markdown]
# ดูชุดข้อมูล ของ ชื่อจังหวัด

# %%
set(data_covid_all['province_of_onset'])
# Out:
# {'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำเพงเพชร',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขอนแก่่น',
#  'ขัยนาท',
#  'ขานุวรลักษณ์บุรี',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ราชบุรี',
#  'จ.สุราษฎร์ธานี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉวาง',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชลบุุรี',
#  'ชอนแก่น',
#  'ชัยนาถ',
#  'ชัยนาท',
#  'ชัยบาดาล',
#  'ชัยภูมิ',
#  'ชัยภูมิ\xa0',
#  'ชุมพร',
#  'ชุุมพร',
#  'ชุุุมพร',
# ...

# %% [markdown]
# ทำการแก้ไขข้อมูลการพิมพ์จังหวัด ที่พิมพ์ผิด  ให้ตรงกับรูปแบบที่กำหนด

# %%
data_covid_all['province_of_onset'].replace({'USA':'ไม่มีข้อมูล','\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                         '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร',
                                         'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร','กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต',
                                         'กัมพูชา':'ไม่มีข้อมูล','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์','กาฬสินธ์':'กาฬสินธุ์',
                                         'กำเพงเพชร':'กำแพงเพชร','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร','กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร',
                                         'ขอนแก่น\xa0':'ขอนแก่น','ขอนแก่่น':'ขอนแก่น','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
                                         'จ.ภูเก็ต':'ภูเก็ต','จ.ราชบุรี':'ราชบุรี','จ.สุราษฎร์ธานี':'สุราษฎร์ธานี','จังหวัดสมุทรสาคร':'สมุทรสาคร','ฉะเชองเทราร':'ฉะเชิงเทรา','ชมพร':'ชุมพร',
                                         'ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชลบุุรี':'ชลบุรี','ชอนแก่น':'ขอนแก่น','ชัยนาถ':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ\xa0':'ชัยภูมิ','ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร',
                                         'ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร','ตรััง':'ตรัง','ตราด\xa0':'ตราด','ตากใบ':'นราธิวาส','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย',
                                         'ท้ายบ้าน':'สมุทรปราการ','ธารโต':'ยะลา','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม','นครนาชสีมา':'นครราชสีมา','นครปฐม\xa0':'นครปฐม',
                                         'นครปบม':'นครปฐม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก','นครราขสีมา':'นครราชสีมา','นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา',
                                         'นครราชสีมา ลพบุรี':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมมราช':'นครศรีธรรมราช',
                                         'นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช',
                                         'นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสรีธรรมราช':'นครศรีธรรมราช','นครสวรรค':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์','นครสีธรรมราช':'นครศรีธรรมราช',
                                         'นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม','นนทบุรี\xa0':'นนทบุรี',
                                         'นนทบุุรี':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส\u200b':'นราธิวาส','นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล',
                                         'นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร','บางปะอิน':'กรุงเทพมหานคร',
                                         'บางละมุง':'ชลบุรี','บางศรีเมือง':'นนทบุรี','บางเพียง':'สมุทรปราการ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรัยม์':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                         'บ้านหลวง':'น่าน','ปจ':'ไม่มีข้อมูล','ปทึมธานี':'ปทุมธานี','ปทุทธานี':'ปทุมธานี','ปทุมฑานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี','ปทุมธาน':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                         'ปธุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานีี':'ปทุมธานี','ปทุุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี',
                                         'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
                                         'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
                                         'ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี', 'ประเทศกัมพูชา':'ไม่มีข้อมูล','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่', 'ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี',
                                         'ปัตตานนี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัว':'น่าน','ปััตตานี':'ปัตตานี','ปุทมธานี':'ปทุมธานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา',
                                         'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พัทยา':'ชลบุรี','พัทลุุง':'พัทลุง','พัังงา':'พังงา',
                                         'พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ฟินแลนด์':'ไม่มีข้อมูล','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็็ต':'ภูเก็ต','ภูเพียง':'น่าน',
                                         'มหาสาคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกาดหาร':'มุกดาหาร','ยานนาวา':'กรุงเทพมหานคร','ร.จ.จ.นราธิวาส':'นราธิวาส','รอ':'ร้อยเอ็ด','ระบุ':'ไม่มีข้อมูล','ระยอง\xa0':'ระยอง',
                                         'ระอยง':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรีี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้องกวาง':'แพร่','ลบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลอง':'แพร่',
                                         'ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำพูน\u200b':'ลำพูน','ลำพููน':'ลำพูน','ลำลูกกา':'ปทุมธานี','วังชิ้น':'ลำปาง','วังทอง':'พิษณุโลก',
                                         'วิเศษชัยชาญ':'อ่างทอง','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ','สครสวรรค์':'นครสวรรค์',
                                         'สงขลา\u200b':'สงขลา','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ','สมทรสงคราม':'สมุทรสงคราม','สมทรสาคร':'สมุทรสาคร','สมุครปราการ':'สมุทรปราการ',
                                         'สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากร':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร',
                                         'สมุทรสาคร\xa0':'สมุทรสาคร','สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ',
                                         'สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม','สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร',
                                         'สระก้ว':'สระแก้ว','สระบุรี\xa0':'สระบุรี','สรินทร์':'สุรินทร์','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สอง':'แพร่','สองแคว':'น่าน','สะพานสูง':'กรุงเทพมหานคร',
                                         'สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล','สามุทรสาคร':'สมุทรสาคร','สารคาม':'มหาสารคาม','สารภี':'เชียงใหม่','สิงห์บุรี\xa0':'สิงห์บุรี',
                                         'สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี\xa0':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                         'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                         'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                         'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์','สุริมทร์':'สุรินทร์',
                                         'สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุพรรณบุรี':'สุพรรณบุรี','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธนี','สุุราษฯ':'สุราษฎร์ธนี','สุุรินทร์':'สุรินทร์',
                                         'สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','สูงเม่น':'แพร่','หนวงบัวลำภู':'หนองบัวลำภู','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู',
                                         'หนองบัวลำพูน':'หนองบัวลำภู','หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หนองม่วงไข่':'แพร่','หนอบัวลำภู':'หนองบัวลำภู','หลายจังหวัด':'ไม่มีข้อมูล','หัวหิน':'ประจวบคีรีขันธ์',
                                         'ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อยุุธยา':'พระนครศรีอยุธยา','อำนาจเจิญ':'อำนาจเจริญ','อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ',
                                         'อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี','อุตรดิตถ์\xa0':'อุตรดิตถ์',
                                         'อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิษถ์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์',
                                         'อุุดรธาน':'อุดรธานี','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อุุบลราชธานี':'อุบลราชธานี','อ่งทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง','อํานาจเจริญ':'อำนาจเจริญ',
                                         'เชิงเทรา':'ฉะเชิงเทรา','เชียรใหญ่':'นครศรีธรรมราช','เชีียงราย':'เชียงราย','เชีียงใหม่':'เชียงใหม่','เด่นชัย':'แพร่','ฉวาง':'ไม่มีข้อมูล','พระพรหม':'ไม่มีข้อมูล','ขัยนาท':'ชัยนาท', 'สุราษฎร์ธนี':'สุราษฎร์ธานี',
                                         'เพขรบุรี':'เพชรบูรณ์','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์','เพชรบุรี':'เพชรบูรณ์','เพชรบุรึ':'เพชรบูรณ์','เพชรบุุรี':'เพชรบูรณ์','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์',
                                         'เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'แพร่','เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','เวียงสา':'น่าน','แม่ทะ':'ลำปาง',
                                         'แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง','ไชโย':'อ่างทอง','ไม่มีข้อมูล':'ไม่มีข้อมูล','ไม่มีชื่อหอพัก':'ไม่มีข้อมูล','ไม่ระบุ':'ไม่มีข้อมูล','สมุทรปรากา':'สมุทรปราการ'}, inplace=True)#

# %%
set(data_covid_all['province_of_onset'])# เรียกดูชุดข้อมูลของ province_of_onset
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สสป.ลาว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธนี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
# ...

# %% [markdown]
# # ข้อมูลภูมิภาค

# %% [markdown]
# ใช้ Dictionary(row oriented) วิธีที่ 1 ของอาจารย์

# %%
data_list = [   {'จังหวัด':'อำนาจเจริญ','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                    {'จังหวัด':'บึงกาฬ','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                    {'จังหวัด':'บุรีรัมย์','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                    {'จังหวัด':'ชัยภูมิ','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                    {'จังหวัด':'กาฬสินธุ์','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'ขอนแก่น','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'เลย','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'มหาสารคาม','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'มุกดาหาร','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'นครพนม','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'นครราชสีมา','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'หนองบัวลำภู','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'หนองคาย','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'ร้อยเอ็ด','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'สกลนคร','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'ศรีสะเกษ','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'สุรินทร์','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'อุบลราชธานี','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                  {'จังหวัด':'อุดรธานี','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
                {'จังหวัด':'ยโสธร','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออกเฉียงเหนือ','4 ภูมิภาค (การเมือง)':'ตะวันออกเฉียงเหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออกเฉียงเหนือ','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออกเฉียงเหนือ'},
    #แถวที่ 2
                    {'จังหวัด':'เชียงใหม่','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':' เชียงราย','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'ลำปาง','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'ลำพูน','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'แม่ฮ่องสอน','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'น่าน','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'พะเยา','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'แพร่','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'อุตรดิตถ์','6 ภูมิภาค (ภูมิศาสตร์)':'เหนือ','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
    #แถวที่ 3
                    {'จังหวัด':'ตาก','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันตก','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
    #แถวที่ 4
                    {'จังหวัด':'สุโขทัย','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'พิษณุโลก','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'พิจิตร','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'กำแพงเพชร','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'เพชรบูรณ์','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'เหนือ','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
    #แถวที่ 5
                    {'จังหวัด':'นครสวรรค์','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
                  {'จังหวัด':'อุทัยธานี','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'เหนือ','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'เหนือ'},
    #แถวที่ 6
                    {'จังหวัด':'อ่างทอง','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'ชัยนาท','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'พระนครศรีอยุธยา','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'กรุงเทพมหานคร','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'ลพบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'นครปฐม','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'นนทบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'ปทุมธานี','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'สมุทรปราการ','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'สมุทรสาคร','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'สมุทรสงคราม','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'สระบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'สิงห์บุรี','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'สุพรรณบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
    #แถวที่ 7
                    {'จังหวัด':'นครนายก','6 ภูมิภาค (ภูมิศาสตร์)':'กลาง','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออก','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
     #แถวที่ 8
                    {'จังหวัด':'ฉะเชิงเทรา','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออก','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออก'},
                  {'จังหวัด':'จันทบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออก','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออก'},
                  {'จังหวัด':'ชลบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออก','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออก'},
                  {'จังหวัด':'ปราจีนบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออก','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออก'},
                  {'จังหวัด':'ระยอง','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออก','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออก'},
                  {'จังหวัด':'สระแก้ว','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออก','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออก'},
                  {'จังหวัด':'ตราด','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันออก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ตะวันออก','5 ภูมิภาค (การท่องเที่ยว)':'ตะวันออก'},
    #แถวที่ 9
                    {'จังหวัด':'กาญจนบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันตก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'ราชบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันตก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'กลาง','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
    #แถวที่ 10
                    {'จังหวัด':'เพชรบุรี','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันตก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
                  {'จังหวัด':'ประจวบคีรีขันธ์','6 ภูมิภาค (ภูมิศาสตร์)':'ตะวันตก','4 ภูมิภาค (การเมือง)':'กลาง','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'กลาง'},
     #แถวที่ 11
                    {'จังหวัด':'ชุมพร','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'นครศรีธรรมราช','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'นราธิวาส','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'ปัตตานี','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'พัทลุง','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'สงขลา','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'สุราษฎร์ธานี','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'ยะลา','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
    #แถวที่ 12               
                    {'จังหวัด':'กระบี่','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'พังงา','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'ภูเก็ต','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'ระนอง','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'สตูล','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},
                  {'จังหวัด':'ตรัง','6 ภูมิภาค (ภูมิศาสตร์)':'ใต้','4 ภูมิภาค (การเมือง)':'ใต้','6 ภูมิภาค (อุตุนิยมวิทยา)':'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','5 ภูมิภาค (การท่องเที่ยว)':'ใต้'},

]

# %%
data_Th = pd.DataFrame(data_list) 
data_Th
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# ..         ...                    ...                  ...
# 72       พังงา                    ใต้                  ใต้
# 73      ภูเก็ต                    ใต้                  ใต้
# 74       ระนอง                    ใต้                  ใต้
# 75        สตูล                    ใต้                  ใต้
# 76        ตรัง                    ใต้                  ใต้
#
#          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)
# 0               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 1               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# ...

# %%
data_Th2 = data_Th[['จังหวัด','5 ภูมิภาค (การท่องเที่ยว)']] #เลือกเฉพาะคอลัมป์ที่ต้องการ
data_Th2
# Out:
#        จังหวัด 5 ภูมิภาค (การท่องเที่ยว)
# 0   อำนาจเจริญ        ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ        ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์        ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ        ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์        ตะวันออกเฉียงเหนือ
# ..         ...                       ...
# 72       พังงา                       ใต้
# 73      ภูเก็ต                       ใต้
# 74       ระนอง                       ใต้
# 75        สตูล                       ใต้
# 76        ตรัง                       ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ## **ทำการรวมตารางข้อมูลรายงาน COVID-19 ประจำประเทศไทย กับ ตารางข้อมูลภูมิภาค**
#
# `` โดยเลือกเอาเฉพาะข้อมูลที่สนใจ``

# %%
Table1_data = data_covid_all[['No.','sex','age','Unit','nationality']] #ตารางแรกเลือกเอาเฉพาะฟิวด์ No.','sex','age',Unit','nationality 
Table1_data.head() #ดูแถวด้านบน 5 แถวแรก
# Out:
#    No.   sex   age Unit nationality
# 0    1  หญิง  61.0   ปี       China
# 1    2  หญิง  74.0   ปี       China
# 2    3  หญิง  73.0   ปี    Thailand
# 3    4   ชาย  68.0   ปี       China
# 4    5  หญิง  66.0   ปี       China

# %%
Table2_data = data_covid_all[['No.','announce_date','province_of_onset','risk']] #ตารางสองเลือกเอาเฉพาะฟิวด์ No.','announce_date','year','month','province_of_onset','risk
Table2_data.tail() #ดูแถวด้านล่าง 5 แถวแรก
# Out:
#              No. announce_date province_of_onset              risk
# 3128785  3353965    2022-03-20       ไม่มีข้อมูล  ทัณฑสถาน/เรือนจำ
# 3128786  3353966    2022-03-20       ไม่มีข้อมูล  ทัณฑสถาน/เรือนจำ
# 3128787  3353967    2022-03-20       ไม่มีข้อมูล  ทัณฑสถาน/เรือนจำ
# 3128788  3353968    2022-03-20       ไม่มีข้อมูล  ทัณฑสถาน/เรือนจำ
# 3128789  3353969    2022-03-20       ไม่มีข้อมูล  ทัณฑสถาน/เรือนจำ

# %%
Table3_data = Table1_data.merge(Table2_data) # นำสองตารางแรกมารวมกันด้วยคำสั่ง merge โดยใช้ฟิวด์No.นำมาเชื่อมกัน
Table3_data.head(10)
# Out:
#    No.   sex   age Unit nationality announce_date province_of_onset  \
# 0    1  หญิง  61.0   ปี       China    2020-01-12     กรุงเทพมหานคร
# 1    1  หญิง  61.0   ปี       China    2020-01-12     กรุงเทพมหานคร
# 2    1  หญิง  61.0   ปี       China    2020-01-12     กรุงเทพมหานคร
# 3    1  หญิง  61.0   ปี       China    2020-01-12     กรุงเทพมหานคร
# 4    2  หญิง  74.0   ปี       China    2020-01-17     กรุงเทพมหานคร
# 5    2  หญิง  74.0   ปี       China    2020-01-17     กรุงเทพมหานคร
# 6    2  หญิง  74.0   ปี       China    2020-01-17     กรุงเทพมหานคร
# 7    2  หญิง  74.0   ปี       China    2020-01-17     กรุงเทพมหานคร
# 8    3  หญิง  73.0   ปี    Thailand    2020-01-22            นครปฐม
# 9    3  หญิง  73.0   ปี    Thailand    2020-01-22            นครปฐม
#
#                                risk
# 0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...

# %%
data_cl = Table3_data.merge(data_Th2,how='right',left_on = 'province_of_onset',right_on = 'จังหวัด')
data_cl
# Out:
#                No.   sex   age Unit nationality announce_date  \
# 0            973.0   ชาย  48.0   ปี    Thailand    2020-03-26
# 1            973.0   ชาย  48.0   ปี    Thailand    2020-03-26
# 2            973.0   ชาย  48.0   ปี    Thailand    2020-03-26
# 3            973.0   ชาย  48.0   ปี    Thailand    2020-03-26
# 4           1864.0  หญิง  46.0   ปี    Thailand    2020-04-02
# ...            ...   ...   ...  ...         ...           ...
# 4200031  3350552.0  หญิง  28.0   ปี    Thailand    2022-03-20
# 4200032  3350553.0  หญิง  53.0   ปี    Thailand    2022-03-20
# 4200033  3350554.0  หญิง  62.0   ปี    Thailand    2022-03-20
# 4200034  3350555.0  หญิง  48.0   ปี    Thailand    2022-03-20
# 4200035  3350556.0   ชาย  50.0   ปี    Thailand    2022-03-20
#
#         province_of_onset                                         risk  \
# 0              อำนาจเจริญ                                  สถานบันเทิง
# 1              อำนาจเจริญ                                  สถานบันเทิง
# ...

# %% [markdown]
# ขั้นตอนต่อมาคือ ตรวจดูชุดข้อมูล ในแต่ละฟิวด์ ว่ามีข้อมูลที่ผิดปกติหรือไม่

# %%
data_cl.isnull().any()
# Out:
# No.                           True
# sex                           True
# age                           True
# Unit                          True
# nationality                   True
# announce_date                 True
# province_of_onset             True
# risk                          True
# จังหวัด                      False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# dtype: bool

# %%
data_cl2 = data_cl.dropna() #ลบแถวที่ Missing

# %%
data_cl2
# Out:
#                No.   sex   age Unit nationality announce_date  \
# 0            973.0   ชาย  48.0   ปี    Thailand    2020-03-26
# 1            973.0   ชาย  48.0   ปี    Thailand    2020-03-26
# 2            973.0   ชาย  48.0   ปี    Thailand    2020-03-26
# 3            973.0   ชาย  48.0   ปี    Thailand    2020-03-26
# 4           1864.0  หญิง  46.0   ปี    Thailand    2020-04-02
# ...            ...   ...   ...  ...         ...           ...
# 4200031  3350552.0  หญิง  28.0   ปี    Thailand    2022-03-20
# 4200032  3350553.0  หญิง  53.0   ปี    Thailand    2022-03-20
# 4200033  3350554.0  หญิง  62.0   ปี    Thailand    2022-03-20
# 4200034  3350555.0  หญิง  48.0   ปี    Thailand    2022-03-20
# 4200035  3350556.0   ชาย  50.0   ปี    Thailand    2022-03-20
#
#         province_of_onset                                         risk  \
# 0              อำนาจเจริญ                                  สถานบันเทิง
# 1              อำนาจเจริญ                                  สถานบันเทิง
# ...

# %%
before = 4200032
after = 4200030
print(f'before = {before} \nafter = {after}\n which is {((before-after)/before)*100}') #พบว่า เปอร์เซ็น missing ที่ dropna = 4.7618684810020496e-05 ซึ่งมีค่าน้อยมากๆ
# Out:
# before = 4200032
# after = 4200030
#  which is 4.7618684810020496e-05

# %%
data_cl2.isnull().any() # ไม่พบค่า True แล้ว
# Out:
# No.                          False
# sex                          False
# age                          False
# Unit                         False
# nationality                  False
# announce_date                False
# province_of_onset            False
# risk                         False
# จังหวัด                      False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# dtype: bool

# %% [markdown]
# **ตรวจดูชุดข้อมูลในแต่ละฟิวด์**

# %%
 set(data_cl2['Unit'])
# Out:
# {' วัน', ' เดือน', 'ปี', 'วัน', 'เดือน', 'ไม่มีข้อมูล'}

# %%
 set(data_cl2['sex']) #เรียกดูชุดข้อมูลของ ฟิวด์ เพศ สังเกตได้ว่า ไม่ได้มีแค่ ชาย-หญิง
# Out:
# {'ช', 'ชาย', 'ญ', 'นาย', 'ร.ต.ท.', 'หญิง', 'หณิง', 'หห', 'ไม่มีข้อมูล'}

# %%
data_cl2.replace({'ปี':'ปี', 'เดือน':'ปี', 'วัน':'ปี', ' เดือน':'ปี', ' วัน':'ปี'},inplace=True) #แทนที่ด้วยค่าที่เหมาะสม
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
data_cl2.replace({'ชาย':'ชาย', 'หญิง':'หญิง','นาย':'ชาย', 'ร.ต.ท.':'ชาย',
       'ช':'ชาย', 'ญ':'หญิง', 'หณิง':'หญิง', 'หห':'ไม่ระบุ'},inplace=True) #แทนที่ด้วยค่าที่เหมาะสม
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
data_cl2.head(10)
# Out:
#       No.   sex   age Unit nationality announce_date province_of_onset  \
# 0   973.0   ชาย  48.0   ปี    Thailand    2020-03-26        อำนาจเจริญ
# 1   973.0   ชาย  48.0   ปี    Thailand    2020-03-26        อำนาจเจริญ
# 2   973.0   ชาย  48.0   ปี    Thailand    2020-03-26        อำนาจเจริญ
# 3   973.0   ชาย  48.0   ปี    Thailand    2020-03-26        อำนาจเจริญ
# 4  1864.0  หญิง  46.0   ปี    Thailand    2020-04-02        อำนาจเจริญ
# 5  1864.0  หญิง  46.0   ปี    Thailand    2020-04-02        อำนาจเจริญ
# 6  1864.0  หญิง  46.0   ปี    Thailand    2020-04-02        อำนาจเจริญ
# 7  1864.0  หญิง  46.0   ปี    Thailand    2020-04-02        อำนาจเจริญ
# 8  6493.0  หญิง  37.0   ปี    Thailand    2020-12-30        อำนาจเจริญ
# 9  6493.0  หญิง  37.0   ปี    Thailand    2020-12-30        อำนาจเจริญ
#
#                             risk     จังหวัด 5 ภูมิภาค (การท่องเที่ยว)
# 0                    สถานบันเทิง  อำนาจเจริญ        ตะวันออกเฉียงเหนือ
# ...

# %%
set(data_cl2['จังหวัด'])
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
# ...

# %% [markdown]
# ## ใช้ข้อมูลตั้งแต่วันที่ 1 มกราคม 2564 ถึง 30 กันยายน 2564

# %%
data_cl3 = data_cl2[(data_cl2['announce_date']>='2021-01-01') & (data_cl2['announce_date']<='2021-09-30')]
data_cl3
# Out:
#               No.   sex   age Unit nationality announce_date  \
# 12         7390.0  หญิง  26.0   ปี        Laos    2021-01-03
# 13         7390.0  หญิง  26.0   ปี        Laos    2021-01-03
# 14         7390.0  หญิง  26.0   ปี        Laos    2021-01-03
# 15         7390.0  หญิง  26.0   ปี        Laos    2021-01-03
# 16        31038.0   ชาย  38.0   ปี    Thailand    2021-04-10
# ...           ...   ...   ...  ...         ...           ...
# 4185768  807718.0   ชาย  17.0   ปี    Thailand    2021-08-11
# 4185769  807719.0   ชาย  50.0   ปี    Thailand    2021-08-11
# 4185770  807719.0   ชาย  50.0   ปี    Thailand    2021-08-11
# 4185771  807719.0   ชาย  50.0   ปี    Thailand    2021-08-11
# 4185772  807719.0   ชาย  50.0   ปี    Thailand    2021-08-11
#
#         province_of_onset                                           risk  \
# 12             อำนาจเจริญ    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13             อำนาจเจริญ    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %% [markdown]
# ## เตรียมข้อมูลสำหรับทำ Dashbaord

# %% [markdown]
# จะเป็นข้อมูลโควิดที่แบ่งตามละจังหวัด

# %%
list_of_province = data_cl3.groupby(['จังหวัด']).count().reset_index().iloc[:,:2] ## หาจำนวนผู้ติดเชื้อโควิค-19 แบ่งตามจังหวัด
list_of_province
# Out:
#           จังหวัด     No.
# 0          กระบี่    3596
# 1   กรุงเทพมหานคร  772804
# 2       กาญจนบุรี   22788
# 3       กาฬสินธุ์   14060
# 4       กำแพงเพชร   15568
# ..            ...     ...
# 70      เชียงใหม่   19696
# 71      เพชรบูรณ์   65780
# 72            เลย    6144
# 73           แพร่    3768
# 74     แม่ฮ่องสอน     472
#
# [75 rows x 2 columns]

# %%
list_of_province.to_csv(os.path.join(path,'covid_province.csv'))

# %% [markdown]
# # ข้อมูลชุดที่ 3  คือ ข้อมูลปริมาณปริมาณการใช้งานเน็ตประชารัฐ

# %%
data_file_path = os.path.join(path,'usage_64_jan.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_31 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_file_path = os.path.join(path,'usage_64_feb.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_32 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_file_path = os.path.join(path,'usage_64_mar.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_33 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_file_path = os.path.join(path,'usage_64_apr.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_34 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_file_path = os.path.join(path,'usage_64_may.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_35 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_file_path = os.path.join(path,'usage_64_jun.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_36 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_file_path = os.path.join(path,'usage_64_jul.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_37 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_file_path = os.path.join(path,'usage_64_aug.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_38 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_file_path = os.path.join(path,'usage_64_sep.xlsx')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_39 = pd.read_excel(data_file_path)   # อ่านไฟล์ excel

# %%
data_internet = pd.concat([data_31,data_32,data_33,data_34,data_35,data_36,data_37,data_38,data_39])
data_internet #รวมตาราง data31-39
# Out:
#             ID    YEAR    MONTH CIRCUIT_NO  APP_CODE REGION  \
# 0          1.0  2564.0   มกราคม  7561d9000  SR664610    ภ.4
# 1          2.0  2564.0   มกราคม  4485d9000  SR711371    ภ.2
# 2          3.0  2564.0   มกราคม  4485d9001  SR711374    ภ.2
# 3          4.0  2564.0   มกราคม  4486d9000  SR711628    ภ.2
# 4          5.0  2564.0   มกราคม  4486d9001  SR711630    ภ.2
# ...        ...     ...      ...        ...       ...    ...
# 24695  24696.0  2564.0  กันยายน  4531d9103  SR740891    ภ.2
# 24696  24697.0  2564.0  กันยายน  4531d9077  SR705346    ภ.2
# 24697  24698.0  2564.0  กันยายน  4531d9078  SR705347    ภ.2
# 24698  24699.0  2564.0  กันยายน  4531d9079  SR705349    ภ.2
# 24699  24700.0  2564.0  กันยายน  4531d9081  SR705352    ภ.2
#
#                    VILLAGE    SUBDISTRICT       DISTRICT     PROVINCE  \
# 0          หมู่ 2 คลองหมาก  เกาะลันตาน้อย      เกาะลันตา       กระบี่
# 1      หมู่ 13 บ้านมะเกลือ        บ้านกอก        จัตุรัส      ชัยภูมิ
# ...

# %%
data_internet.isnull().any() #ตรวจสอบค่า Missing
# Out:
# ID             False
# YEAR           False
# MONTH          False
# CIRCUIT_NO     False
# APP_CODE       False
# REGION         False
# VILLAGE        False
# SUBDISTRICT    False
# DISTRICT       False
# PROVINCE       False
# AP_NAME        False
# IP_ADDRESS     False
# UPLOAD         False
# DOWNLOAD       False
# NUM_USERS      False
# NUM_DEVICES    False
# dtype: bool

# %%
data_internet1 = data_internet[['YEAR','MONTH','REGION','VILLAGE','SUBDISTRICT','DISTRICT','PROVINCE','NUM_USERS','NUM_DEVICES']]
data_internet1 # เลือกเฉพาะคอลัมน์ที่ต้องการ
# Out:
#          YEAR    MONTH REGION              VILLAGE    SUBDISTRICT  \
# 0      2564.0   มกราคม    ภ.4      หมู่ 2 คลองหมาก  เกาะลันตาน้อย
# 1      2564.0   มกราคม    ภ.2  หมู่ 13 บ้านมะเกลือ        บ้านกอก
# 2      2564.0   มกราคม    ภ.2   หมู่ 17 บ้านโนนทอง        บ้านกอก
# 3      2564.0   มกราคม    ภ.2          หมู่ 1 เพชร       บ้านเพชร
# 4      2564.0   มกราคม    ภ.2       หมู่ 8 เพชรใต้       บ้านเพชร
# ...       ...      ...    ...                  ...            ...
# 24695  2564.0  กันยายน    ภ.2           หมู่ 3 แดง        แพงใหญ่
# 24696  2564.0  กันยายน    ภ.2       หมู่ 7 รังแร้ง       โพนเมือง
# 24697  2564.0  กันยายน    ภ.2       หมู่ 9 ดอนกลอย       โพนเมือง
# 24698  2564.0  กันยายน    ภ.2       หมู่ 12 โชคชัย       โพนเมือง
# 24699  2564.0  กันยายน    ภ.2       หมู่ 17 นากลาง       โพนเมือง
#
#             DISTRICT     PROVINCE  NUM_USERS  NUM_DEVICES
# 0          เกาะลันตา       กระบี่     1179.0        168.0
# ...

# %%
set(data_internet1['REGION']) #เช็คชุดของมูลภูมิภาค ของชุดที่ 3
# Out:
# {'น.2', 'น.3', 'น.4', 'ภ.1', 'ภ.2', 'ภ.3', 'ภ.4', 'ภ.5'}

# %%
data_internet1.replace({'น.2':'กลาง', 'น.3':'กลาง', 'น.4':'กลาง', 'ภ.1':'กลาง', 'ภ.2':'ตะวันออกเฉียงเหนือ', 'ภ.3':'เหนือ','ภ.4':'ใต้','ภ.5':'ตะวันออก'},inplace=True) #แทนที่ด้วยค่าที่เหมาะสม
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
set(data_internet1['PROVINCE']) #เรียกดูชุดข้อมูลอีกครั้ง พบว่ารายชื่อจังหวัดถูกต้อง ตรงตาม ที่ต้องการแล้ว
# Out:
# {'กระบี่',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
# ...

# %%
data_internet1
# Out:
#          YEAR    MONTH              REGION              VILLAGE  \
# 0      2564.0   มกราคม                 ใต้      หมู่ 2 คลองหมาก
# 1      2564.0   มกราคม  ตะวันออกเฉียงเหนือ  หมู่ 13 บ้านมะเกลือ
# 2      2564.0   มกราคม  ตะวันออกเฉียงเหนือ   หมู่ 17 บ้านโนนทอง
# 3      2564.0   มกราคม  ตะวันออกเฉียงเหนือ          หมู่ 1 เพชร
# 4      2564.0   มกราคม  ตะวันออกเฉียงเหนือ       หมู่ 8 เพชรใต้
# ...       ...      ...                 ...                  ...
# 24695  2564.0  กันยายน  ตะวันออกเฉียงเหนือ           หมู่ 3 แดง
# 24696  2564.0  กันยายน  ตะวันออกเฉียงเหนือ       หมู่ 7 รังแร้ง
# 24697  2564.0  กันยายน  ตะวันออกเฉียงเหนือ       หมู่ 9 ดอนกลอย
# 24698  2564.0  กันยายน  ตะวันออกเฉียงเหนือ       หมู่ 12 โชคชัย
# 24699  2564.0  กันยายน  ตะวันออกเฉียงเหนือ       หมู่ 17 นากลาง
#
#          SUBDISTRICT       DISTRICT     PROVINCE  NUM_USERS  NUM_DEVICES
# 0      เกาะลันตาน้อย      เกาะลันตา       กระบี่     1179.0        168.0
# ...

# %% [markdown]
# # รวมข้อมูล

# %%
data_allall = list_of_province.merge(data_internet1,how='right',left_on = 'จังหวัด',right_on ='PROVINCE') # ทำการเชื่อมตารางโดยใช้ คีย์หลัก คือ จังหวัดกับ PROVINCE
data_allall
# Out:
#             จังหวัด     No.    YEAR    MONTH              REGION  \
# 0            กระบี่  3596.0  2564.0   มกราคม                 ใต้
# 1           ชัยภูมิ  3704.0  2564.0   มกราคม  ตะวันออกเฉียงเหนือ
# 2           ชัยภูมิ  3704.0  2564.0   มกราคม  ตะวันออกเฉียงเหนือ
# 3           ชัยภูมิ  3704.0  2564.0   มกราคม  ตะวันออกเฉียงเหนือ
# 4           ชัยภูมิ  3704.0  2564.0   มกราคม  ตะวันออกเฉียงเหนือ
# ...             ...     ...     ...      ...                 ...
# 222295  อุบลราชธานี  6372.0  2564.0  กันยายน  ตะวันออกเฉียงเหนือ
# 222296  อุบลราชธานี  6372.0  2564.0  กันยายน  ตะวันออกเฉียงเหนือ
# 222297  อุบลราชธานี  6372.0  2564.0  กันยายน  ตะวันออกเฉียงเหนือ
# 222298  อุบลราชธานี  6372.0  2564.0  กันยายน  ตะวันออกเฉียงเหนือ
# 222299  อุบลราชธานี  6372.0  2564.0  กันยายน  ตะวันออกเฉียงเหนือ
#
#                     VILLAGE    SUBDISTRICT       DISTRICT     PROVINCE  \
# 0           หมู่ 2 คลองหมาก  เกาะลันตาน้อย      เกาะลันตา       กระบี่
# ...

# %%
data_allall.replace({'มกราคม':'1', 'กุมภาพันธ์':'2','มีนาคม':'3', 'เมษายน':'4',
       'พฤษภาคม':'5', 'มิถุนายน':'6', 'กรกฎาคม':'7', 'สิงหาคม':'8', 'กันยายน':'9'},inplace=True) #แทนที่ด้วยค่าที่เหมาะสม

# %%
data_allall
# Out:
#             จังหวัด     No.    YEAR MONTH              REGION  \
# 0            กระบี่  3596.0  2564.0     1                 ใต้
# 1           ชัยภูมิ  3704.0  2564.0     1  ตะวันออกเฉียงเหนือ
# 2           ชัยภูมิ  3704.0  2564.0     1  ตะวันออกเฉียงเหนือ
# 3           ชัยภูมิ  3704.0  2564.0     1  ตะวันออกเฉียงเหนือ
# 4           ชัยภูมิ  3704.0  2564.0     1  ตะวันออกเฉียงเหนือ
# ...             ...     ...     ...   ...                 ...
# 222295  อุบลราชธานี  6372.0  2564.0     9  ตะวันออกเฉียงเหนือ
# 222296  อุบลราชธานี  6372.0  2564.0     9  ตะวันออกเฉียงเหนือ
# 222297  อุบลราชธานี  6372.0  2564.0     9  ตะวันออกเฉียงเหนือ
# 222298  อุบลราชธานี  6372.0  2564.0     9  ตะวันออกเฉียงเหนือ
# 222299  อุบลราชธานี  6372.0  2564.0     9  ตะวันออกเฉียงเหนือ
#
#                     VILLAGE    SUBDISTRICT       DISTRICT     PROVINCE  \
# 0           หมู่ 2 คลองหมาก  เกาะลันตาน้อย      เกาะลันตา       กระบี่
# 1       หมู่ 13 บ้านมะเกลือ        บ้านกอก        จัตุรัส      ชัยภูมิ
# ...

# %%
data_dashd = data_allall[['PROVINCE','No.','MONTH','REGION','DISTRICT','SUBDISTRICT','NUM_USERS','NUM_DEVICES']]
print(data_dashd.shape)  # ดูขนาดของ data frame
data_dashd
# Out:
# (222300, 8)
#            PROVINCE     No. MONTH              REGION       DISTRICT  \
# 0            กระบี่  3596.0     1                 ใต้      เกาะลันตา
# 1           ชัยภูมิ  3704.0     1  ตะวันออกเฉียงเหนือ        จัตุรัส
# 2           ชัยภูมิ  3704.0     1  ตะวันออกเฉียงเหนือ        จัตุรัส
# 3           ชัยภูมิ  3704.0     1  ตะวันออกเฉียงเหนือ        ภูเขียว
# 4           ชัยภูมิ  3704.0     1  ตะวันออกเฉียงเหนือ        ภูเขียว
# ...             ...     ...   ...                 ...            ...
# 222295  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
# 222296  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
# 222297  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
# 222298  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
# 222299  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
#
#           SUBDISTRICT  NUM_USERS  NUM_DEVICES
# 0       เกาะลันตาน้อย     1179.0        168.0
# ...

# %%
data_dashd.isnull().any() #ตรวจสอบ Missing
# Out:
# PROVINCE       False
# No.             True
# MONTH          False
# REGION         False
# DISTRICT       False
# SUBDISTRICT    False
# NUM_USERS      False
# NUM_DEVICES    False
# dtype: bool

# %%
data_dashb_3 = data_dashd.dropna() #ลบค่า  Missing  ออก
data_dashb_3
# Out:
#            PROVINCE     No. MONTH              REGION       DISTRICT  \
# 0            กระบี่  3596.0     1                 ใต้      เกาะลันตา
# 1           ชัยภูมิ  3704.0     1  ตะวันออกเฉียงเหนือ        จัตุรัส
# 2           ชัยภูมิ  3704.0     1  ตะวันออกเฉียงเหนือ        จัตุรัส
# 3           ชัยภูมิ  3704.0     1  ตะวันออกเฉียงเหนือ        ภูเขียว
# 4           ชัยภูมิ  3704.0     1  ตะวันออกเฉียงเหนือ        ภูเขียว
# ...             ...     ...   ...                 ...            ...
# 222295  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
# 222296  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
# 222297  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
# 222298  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
# 222299  อุบลราชธานี  6372.0     9  ตะวันออกเฉียงเหนือ  เหล่าเสือโก้ก
#
#           SUBDISTRICT  NUM_USERS  NUM_DEVICES
# 0       เกาะลันตาน้อย     1179.0        168.0
# ...

# %%
before = 222300
after = 219492
print(f'before = {before} \nafter = {after}\n which is {((before-after)/before)*100}') #พบว่า เปอร์เซ็น missing ที่ dropna = 1.263157894736842ซึ่งมีค่าน้อยมากๆ
# Out:
# before = 222300
# after = 219492
#  which is 1.263157894736842

# %%
data_dashb_3.to_csv(os.path.join(path,'covid_co3.csv')) #บันทึกไฟล์ เพื่อนำไปจัดทำ Dashboard

# %% [markdown]
# # Link Dashboard

# %% [markdown]
# https://datastudio.google.com/reporting/21e65bea-af4a-4907-829d-5b4e8feeba06
