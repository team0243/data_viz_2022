# %% [markdown]
# <a href="https://colab.research.google.com/github/team0243/data_viz_2022/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project กลุ่ม Therapy Python**
#
# ``ทำ Dashboard ของ Data Covid (ตั้งแต่วันที่ 12/01/2020 - 20/03/2022) เล่ามุมมองที่เราเลือกเอง + ใช้ข้อมูลภูมิภาค + ข้อมูลอื่นที่เลือกเอง``
# ``
# เริ่มพรีเซ็นต์ 25 มีค 30 มีค 1 เมษา
# ``
#
# ** ที่มาของข้อมูล **
#
# 1.ข้อมูลรายงาน COVID-19 ประจำประเทศไทย
#
# https://data.go.th/dataset/covid-19-daily ประกอบด้วย 4 ชุดข้อมูลได้แก่
#
# 1.1 รายงานจำนวนผู้ติดเชื้อ COVID-19 ตั้งแต่วันที่ 12 มกราคม 2564 ถึงวันที่ 12 สิงหาคม 2564
#
# 1.2 รายงานจำนวนผู้ติดเชื้อ COVID-19 ตั้งแต่วันที่ 12 สิงหาคม 2564 ถึงวันที่ 25 ตุลาคม 2564
#
# 1.3 รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน ตั้งแต่วันที่ 25 ตุลาคม 2564 ถึงวันที่ 27 กุมภาพันธ์ 2565
#
# 1.4 รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน ตั้งแต่วันที่ 28 กุมภาพันธ์ 2565 ถึงวันที่ 20 มีนาคม 2565
#
# 2.ข้อมูลอื่นที่เลือกเอง

# %% [markdown]
# # อัพโหลดข้อมูลจาก Drive

# %%
import numpy as np

# %%
import pandas as pd     # pandas ใช้จัดการข้อมูลที่เป็นตาราง
import os       # os ใช้จัดการกับไฟล์ ว่าอยู่ที่ไหน

# %%
from google.colab import drive      # ชี้ไฟล์ที่อยู่ใน google drive เพื่อเชื่อมต่อไฟล์
drive.mount('/content/drive')
path =  '/content/drive/My Drive/Data_viz_project'    # ชี้ dirve ที่เราต้องการ
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# เตรียมข้อมูลData covid ทั้ง 4 ชุด

# %% [markdown]
# ข้อมูลชุดที่ 1  รายงานจำนวนผู้ติดเชื้อ COVID-19 ตั้งแต่วันที่ 12 มกราคม 2564 ถึงวันที่ 12 สิงหาคม 2564

# %%
data_file_path = os.path.join(path,'confirmed-cases.csv')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_covid1 = pd.read_csv(data_file_path)   # อ่านไฟล์ csv
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
display(data_covid1.head(2),data_covid1.tail(2))
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1    2     17/1/2020           NaN  หญิง  74.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0               NaN
# 1               NaN
#            No. announce_date Notified date  sex   age Unit nationality  \
# 839769  839770     12/8/2021     11/8/2021  ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021  ชาย  47.0   ปี    Thailand
#
#        province_of_isolation              risk province_of_onset  \
# 839769             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839770             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
#
#        district_of_onset
# 839769               NaN
# 839770               NaN

# %% [markdown]
# ข้อมูลชุดที่ 2 รายงานจำนวนผู้ติดเชื้อ COVID-19 ตั้งแต่วันที่ 12 สิงหาคม 2564 ถึงวันที่ 25 ตุลาคม 2564

# %%
data_file_path = os.path.join(path,'confirmed-cases-since-120864.csv')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_covid2 = pd.read_csv(data_file_path)   # อ่านไฟล์ csv

# %%
display(data_covid2.head(2),data_covid2.tail(2))
# Out:
#       No. announce_date Notified date  sex  age Unit nationality  \
# 0  816990     12/8/2021     11/8/2021  ชาย  7.0   ปี    Thailand
# 1  816991     12/8/2021     11/8/2021  ชาย  1.0   ปี    Thailand
#
#   province_of_isolation   risk province_of_onset district_of_onset
# 0              เชียงราย  อื่นๆ               NaN               NaN
# 1              เชียงราย  อื่นๆ               NaN               NaN
#              No. announce_date Notified date  sex   age Unit nationality  \
# 1042166  1859156    25/10/2021    24/10/2021  ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021  ชาย  25.0   ปี         NaN
#
#         province_of_isolation              risk province_of_onset  \
# 1042166         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ               NaN
# 1042167             เชียงใหม่  ทัณฑสถาน/เรือนจำ               NaN
#
#         district_of_onset
# 1042166               NaN
# 1042167               NaN

# %% [markdown]
# ข้อมูลชุดที่ 3 รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน ตั้งแต่วันที่ 25ตุลาคม 2564 ถึงวันที่ 27 กุมภาพันธ์ 2565

# %%
data_file_path = os.path.join(path,'confirmed-cases-since-271064.csv')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_covid3 = pd.read_csv(data_file_path)   # อ่านไฟล์ csv
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
display(data_covid3.head(2),data_covid3.tail(2))
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1  1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
#
#   province_of_isolation   risk province_of_onset district_of_onset  \
# 0                 ลำปาง  อื่นๆ             ลำปาง        เมืองลำปาง
# 1                 ลำปาง  อื่นๆ             ลำปาง        เมืองลำปาง
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
#              No. announce_date Notified date  sex  age Unit nationality  \
# 1010457  2869615     27/2/2022     26/2/2022  ชาย  NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022  ชาย  NaN  NaN         NaN
#
#         province_of_isolation              risk province_of_onset  \
# 1010457               ปัตตานี  ทัณฑสถาน/เรือนจำ               NaN
# 1010458               ปัตตานี  ทัณฑสถาน/เรือนจำ               NaN
#
#         district_of_onset  Unnamed: 11
# 1010457               NaN          NaN
# 1010458               NaN          NaN

# %% [markdown]
# ข้อมูลชุดที่ 4 รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน ตั้งแต่วันที่ 28 กุมภาพันธ์ 2565 ถึงวันที่ 20 มีนาคม 2565

# %%
data_file_path = os.path.join(path,'confirmed-cases-since-280265.csv')   # ดึงไฟล์จากไดร์ฟที่เราต้องการ
data_covid4 = pd.read_csv(data_file_path)   # อ่านไฟล์ csv

# %%
display(data_covid4.head(2),data_covid4.tail(2))
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1  2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
#
#   province_of_isolation                                         risk  \
# 0                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset
# 0             พะเยา        เมืองพะเยา
# 1             พะเยา        เมืองพะเยา
#             No. announce_date Notified date  sex  age Unit nationality  \
# 484351  3353968     20/3/2022     19/3/2022  ชาย  NaN  NaN         NaN
# 484352  3353969     20/3/2022     19/3/2022  ชาย  NaN  NaN         NaN
#
#        province_of_isolation              risk province_of_onset  \
# 484351             เชียงใหม่  ทัณฑสถาน/เรือนจำ               NaN
# 484352             เชียงใหม่  ทัณฑสถาน/เรือนจำ               NaN
#
#        district_of_onset
# 484351               NaN
# 484352               NaN

# %% [markdown]
# ขั้นตอนถัดไป คือ การรวมข้อมูลารางทั้ง 4 ชุด เข้าด้วยกัน และจัดเรียงตามลำดับก่อน-หลัง

# %%
data_covid_all =pd.concat([data_covid1,data_covid2,data_covid3,data_covid4], ignore_index=True)
data_covid_all
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0              1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1              2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2              3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3              4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4              5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...          ...           ...           ...   ...   ...  ...         ...
# 3376746  3353965     20/3/2022     19/3/2022   ชาย   NaN  NaN         NaN
# 3376747  3353966     20/3/2022     19/3/2022   ชาย   NaN  NaN         NaN
# 3376748  3353967     20/3/2022     19/3/2022   ชาย   NaN  NaN         NaN
# 3376749  3353968     20/3/2022     19/3/2022   ชาย   NaN  NaN         NaN
# 3376750  3353969     20/3/2022     19/3/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                              risk  \
# 0               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                      นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                     นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                       ...                               ...
# 3376746             เชียงใหม่                  ทัณฑสถาน/เรือนจำ
# 3376747             เชียงใหม่                  ทัณฑสถาน/เรือนจำ
# 3376748             เชียงใหม่                  ทัณฑสถาน/เรือนจำ
# 3376749             เชียงใหม่                  ทัณฑสถาน/เรือนจำ
# 3376750             เชียงใหม่                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0           กรุงเทพมหานคร               NaN          NaN
# 1           กรุงเทพมหานคร               NaN          NaN
# 2                  นครปฐม             เมือง          NaN
# 3           กรุงเทพมหานคร               NaN          NaN
# 4           กรุงเทพมหานคร               NaN          NaN
# ...                   ...               ...          ...
# 3376746               NaN               NaN          NaN
# 3376747               NaN               NaN          NaN
# 3376748               NaN               NaN          NaN
# 3376749               NaN               NaN          NaN
# 3376750               NaN               NaN          NaN
#
# [3376751 rows x 12 columns]

# %% [markdown]
# เช็คดู ค่า Missing

# %%
data_covid_all.isnull() #เช็คดูค่า Missing ทั้งหมด
# Out:
#            No.  announce_date  Notified date    sex    age   Unit  \
# 0        False          False           True  False  False  False
# 1        False          False           True  False  False  False
# 2        False          False           True  False  False  False
# 3        False          False           True  False  False  False
# 4        False          False           True  False  False  False
# ...        ...            ...            ...    ...    ...    ...
# 3376746  False          False          False  False   True   True
# 3376747  False          False          False  False   True   True
# 3376748  False          False          False  False   True   True
# 3376749  False          False          False  False   True   True
# 3376750  False          False          False  False   True   True
#
#          nationality  province_of_isolation   risk  province_of_onset  \
# 0              False                  False  False              False
# 1              False                  False  False              False
# 2              False                  False  False              False
# 3              False                  False  False              False
# 4              False                  False  False              False
# ...              ...                    ...    ...                ...
# 3376746         True                  False  False               True
# 3376747         True                  False  False               True
# 3376748         True                  False  False               True
# 3376749         True                  False  False               True
# 3376750         True                  False  False               True
#
#          district_of_onset  Unnamed: 11
# 0                     True         True
# 1                     True         True
# 2                    False         True
# 3                     True         True
# 4                     True         True
# ...                    ...          ...
# 3376746               True         True
# 3376747               True         True
# 3376748               True         True
# 3376749               True         True
# 3376750               True         True
#
# [3376751 rows x 12 columns]

# %%
data_covid_all.isnull() .any() # เช็คดูค่า Missing ในแต่ละ คอลัมป์
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# Unnamed: 11               True
# dtype: bool

# %% [markdown]
# ขั้นตอนต่อมาคือการทำความสะอาดข้อมูล Data cleanning

# %% [markdown]
# **1.เลือกเฉพาะฟิวด์ที่ใช้ ได้แก่ announce_date,	sex,	age	,Unit,	nationality risk	และ province_of_onset**

# %%
data_p1 = data_covid_all[['No.','announce_date','sex','age','Unit','province_of_onset','risk']]
data_p1
# Out:
#              No. announce_date   sex   age Unit province_of_onset  \
# 0              1     12/1/2020  หญิง  61.0   ปี     กรุงเทพมหานคร
# 1              2     17/1/2020  หญิง  74.0   ปี     กรุงเทพมหานคร
# 2              3     22/1/2020  หญิง  73.0   ปี            นครปฐม
# 3              4     22/1/2020   ชาย  68.0   ปี     กรุงเทพมหานคร
# 4              5     24/1/2020  หญิง  66.0   ปี     กรุงเทพมหานคร
# ...          ...           ...   ...   ...  ...               ...
# 3376746  3353965     20/3/2022   ชาย   NaN  NaN               NaN
# 3376747  3353966     20/3/2022   ชาย   NaN  NaN               NaN
# 3376748  3353967     20/3/2022   ชาย   NaN  NaN               NaN
# 3376749  3353968     20/3/2022   ชาย   NaN  NaN               NaN
# 3376750  3353969     20/3/2022   ชาย   NaN  NaN               NaN
#
#                                      risk
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                   ...
# 3376746                  ทัณฑสถาน/เรือนจำ
# 3376747                  ทัณฑสถาน/เรือนจำ
# 3376748                  ทัณฑสถาน/เรือนจำ
# 3376749                  ทัณฑสถาน/เรือนจำ
# 3376750                  ทัณฑสถาน/เรือนจำ
#
# [3376751 rows x 7 columns]

# %% [markdown]
# **2.ฟิวด์ age เปลี่ยนค่า Nan ให้เป็นค่าเฉลี่ย ของอายุ**

# %%
data_covid2[['age']].mean() # หาค่าเฉลี่ยของอายุ พบว่าอายุเฉลี่ย ประมาณ 35 ปี
# Out:
# age    35.258596
# dtype: float64

# %%
 data_p1[['age']] = data_p1[['age']].fillna('35.0')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_p1.isnull() .any() # พบว่า ฟิวด์ของ age เป็นค่า false แล้ว
# Out:
# No.                  False
# announce_date        False
# sex                   True
# age                  False
# Unit                  True
# province_of_onset     True
# risk                  True
# dtype: bool

# %%
data_p1
# Out:
#              No. announce_date   sex   age Unit province_of_onset  \
# 0              1     12/1/2020  หญิง  61.0   ปี     กรุงเทพมหานคร
# 1              2     17/1/2020  หญิง  74.0   ปี     กรุงเทพมหานคร
# 2              3     22/1/2020  หญิง  73.0   ปี            นครปฐม
# 3              4     22/1/2020   ชาย  68.0   ปี     กรุงเทพมหานคร
# 4              5     24/1/2020  หญิง  66.0   ปี     กรุงเทพมหานคร
# ...          ...           ...   ...   ...  ...               ...
# 3376746  3353965     20/3/2022   ชาย  35.0  NaN               NaN
# 3376747  3353966     20/3/2022   ชาย  35.0  NaN               NaN
# 3376748  3353967     20/3/2022   ชาย  35.0  NaN               NaN
# 3376749  3353968     20/3/2022   ชาย  35.0  NaN               NaN
# 3376750  3353969     20/3/2022   ชาย  35.0  NaN               NaN
#
#                                      risk
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                   ...
# 3376746                  ทัณฑสถาน/เรือนจำ
# 3376747                  ทัณฑสถาน/เรือนจำ
# 3376748                  ทัณฑสถาน/เรือนจำ
# 3376749                  ทัณฑสถาน/เรือนจำ
# 3376750                  ทัณฑสถาน/เรือนจำ
#
# [3376751 rows x 7 columns]
